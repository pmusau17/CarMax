# %%
'''Load Packages'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import warnings
from sklearn.cluster import KMeans 
import random
from sklearn import metrics 
from scipy.spatial.distance import cdist

# %%
convertible0 = pd.read_csv('clustersGrouped/convertibleCluster0.csv')
convertible1 = pd.read_csv('clustersGrouped/convertibleCluster1.csv')
convertible2 = pd.read_csv('clustersGrouped/convertibleCluster2.csv')
convertible3 = pd.read_csv('clustersGrouped/convertibleCluster3.csv')
convertible4 = pd.read_csv('clustersGrouped/convertibleCluster4.csv')
convertible5 = pd.read_csv('clustersGrouped/convertibleCluster5.csv')

# %% [markdown]
# ### Purchase_Make

# %%
pd.concat([convertible0.groupby('purchase_make').count().rename(columns={'trade_in':"convertible0"})[['convertible0']],
           convertible1.groupby('purchase_make').count().rename(columns={'trade_in':"convertible1"})[['convertible1']],
          convertible2.groupby('purchase_make').count().rename(columns={'trade_in':"convertible2"})[['convertible2']],
          convertible3.groupby('purchase_make').count().rename(columns={'trade_in':"convertible3"})[['convertible3']],
          convertible4.groupby('purchase_make').count().rename(columns={'trade_in':"convertible4"})[['convertible4']],
          convertible5.groupby('purchase_make').count().rename(columns={'trade_in':"convertible5"})[['convertible5']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_1ddc29b1_51e9_11eb_8bb3_9cfce8076f42row3_col4 {
#             background-color:  green;
#         }    #T_1ddc29b1_51e9_11eb_8bb3_9cfce8076f42row7_col0 {
#             background-color:  green;
#         }    #T_1ddc29b1_51e9_11eb_8bb3_9cfce8076f42row7_col3 {
#             background-color:  green;
#         }    #T_1ddc29b1_51e9_11eb_8bb3_9cfce8076f42row14_col1 {
#             background-color:  green;
#         }    #T_1ddc29b1_51e9_11eb_8bb3_9cfce8076f42row15_col2 {
#             background-color:  green;
#         }    #T_1ddc29b1_51e9_11eb_8bb3_9cfce8076f42row15_col5 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Purchase_Model

# %%
pd.concat([convertible0.groupby('purchase_model').count().rename(columns={'trade_in':"convertible0"})[['convertible0']],
           convertible1.groupby('purchase_model').count().rename(columns={'trade_in':"convertible1"})[['convertible1']],
          convertible2.groupby('purchase_model').count().rename(columns={'trade_in':"convertible2"})[['convertible2']],
          convertible3.groupby('purchase_model').count().rename(columns={'trade_in':"convertible3"})[['convertible3']],
          convertible4.groupby('purchase_model').count().rename(columns={'trade_in':"convertible4"})[['convertible4']],
          convertible5.groupby('purchase_model').count().rename(columns={'trade_in':"convertible5"})[['convertible5']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_78b70e65_51e9_11eb_83c3_9cfce8076f42row8_col4 {
#             background-color:  green;
#         }    #T_78b70e65_51e9_11eb_83c3_9cfce8076f42row35_col0 {
#             background-color:  green;
#         }    #T_78b70e65_51e9_11eb_83c3_9cfce8076f42row35_col3 {
#             background-color:  green;
#         }    #T_78b70e65_51e9_11eb_83c3_9cfce8076f42row39_col1 {
#             background-color:  green;
#         }    #T_78b70e65_51e9_11eb_83c3_9cfce8076f42row43_col2 {
#             background-color:  green;
#         }    #T_78b70e65_51e9_11eb_83c3_9cfce8076f42row43_col5 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Customer_Income

# %%
pd.concat([convertible0.groupby('customer_income').count().rename(columns={'trade_in':"convertible0"})[['convertible0']],
           convertible1.groupby('customer_income').count().rename(columns={'trade_in':"convertible1"})[['convertible1']],
          convertible2.groupby('customer_income').count().rename(columns={'trade_in':"convertible2"})[['convertible2']],
          convertible3.groupby('customer_income').count().rename(columns={'trade_in':"convertible3"})[['convertible3']],
          convertible4.groupby('customer_income').count().rename(columns={'trade_in':"convertible4"})[['convertible4']],
          convertible5.groupby('customer_income').count().rename(columns={'trade_in':"convertible5"})[['convertible5']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_7989051a_51e9_11eb_af44_9cfce8076f42row7_col1 {
#             background-color:  green;
#         }    #T_7989051a_51e9_11eb_af44_9cfce8076f42row8_col0 {
#             background-color:  green;
#         }    #T_7989051a_51e9_11eb_af44_9cfce8076f42row8_col2 {
#             background-color:  green;
#         }    #T_7989051a_51e9_11eb_af44_9cfce8076f42row8_col5 {
#             background-color:  green;
#         }    #T_7989051a_51e9_11eb_af44_9cfce8076f42row9_col4 {
#             background-color:  green;
#         }    #T_7989051a_51e9_11eb_af44_9cfce8076f42row11_col3 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Made_In

# %%
pd.concat([convertible0.groupby('made_in').count().rename(columns={'trade_in':"convertible0"})[['convertible0']],
           convertible1.groupby('made_in').count().rename(columns={'trade_in':"convertible1"})[['convertible1']],
          convertible2.groupby('made_in').count().rename(columns={'trade_in':"convertible2"})[['convertible2']],
          convertible3.groupby('made_in').count().rename(columns={'trade_in':"convertible3"})[['convertible3']],
          convertible4.groupby('made_in').count().rename(columns={'trade_in':"convertible4"})[['convertible4']],
          convertible5.groupby('made_in').count().rename(columns={'trade_in':"convertible5"})[['convertible5']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_7a4a3772_51e9_11eb_bcdb_9cfce8076f42row0_col0 {
#             background-color:  green;
#         }    #T_7a4a3772_51e9_11eb_bcdb_9cfce8076f42row0_col3 {
#             background-color:  green;
#         }    #T_7a4a3772_51e9_11eb_bcdb_9cfce8076f42row3_col2 {
#             background-color:  green;
#         }    #T_7a4a3772_51e9_11eb_bcdb_9cfce8076f42row3_col4 {
#             background-color:  green;
#         }    #T_7a4a3772_51e9_11eb_bcdb_9cfce8076f42row3_col5 {
#             background-color:  green;
#         }    #T_7a4a3772_51e9_11eb_bcdb_9cfce8076f42row5_col1 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Customer_Gender

# %%
pd.concat([convertible0.groupby('customer_gender').count().rename(columns={'trade_in':"convertible0"})[['convertible0']],
           convertible1.groupby('customer_gender').count().rename(columns={'trade_in':"convertible1"})[['convertible1']],
          convertible2.groupby('customer_gender').count().rename(columns={'trade_in':"convertible2"})[['convertible2']],
          convertible3.groupby('customer_gender').count().rename(columns={'trade_in':"convertible3"})[['convertible3']],
          convertible4.groupby('customer_gender').count().rename(columns={'trade_in':"convertible4"})[['convertible4']],
          convertible5.groupby('customer_gender').count().rename(columns={'trade_in':"convertible5"})[['convertible5']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_7b472630_51e9_11eb_b6ab_9cfce8076f42row1_col0 {
#             background-color:  green;
#         }    #T_7b472630_51e9_11eb_b6ab_9cfce8076f42row1_col1 {
#             background-color:  green;
#         }    #T_7b472630_51e9_11eb_b6ab_9cfce8076f42row1_col2 {
#             background-color:  green;
#         }    #T_7b472630_51e9_11eb_b6ab_9cfce8076f42row1_col3 {
#             background-color:  green;
#         }    #T_7b472630_51e9_11eb_b6ab_9cfce8076f42row1_col4 {
#             background-color:  green;
#         }    #T_7b472630_51e9_11eb_b6ab_9cfce8076f42row1_col5 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Trade_In

# %%
pd.concat([convertible0.groupby('trade_in').count().rename(columns={'made_in':"convertible0"})[['convertible0']],
           convertible1.groupby('trade_in').count().rename(columns={'made_in':"convertible1"})[['convertible1']],
          convertible2.groupby('trade_in').count().rename(columns={'made_in':"convertible2"})[['convertible2']],
          convertible3.groupby('trade_in').count().rename(columns={'made_in':"convertible3"})[['convertible3']],
          convertible4.groupby('trade_in').count().rename(columns={'made_in':"convertible4"})[['convertible4']],
          convertible5.groupby('trade_in').count().rename(columns={'made_in':"convertible5"})[['convertible5']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_7cb6a8e2_51e9_11eb_9fc6_9cfce8076f42row0_col1 {
#             background-color:  green;
#         }    #T_7cb6a8e2_51e9_11eb_9fc6_9cfce8076f42row0_col2 {
#             background-color:  green;
#         }    #T_7cb6a8e2_51e9_11eb_9fc6_9cfce8076f42row0_col3 {
#             background-color:  green;
#         }    #T_7cb6a8e2_51e9_11eb_9fc6_9cfce8076f42row0_col4 {
#             background-color:  green;
#         }    #T_7cb6a8e2_51e9_11eb_9fc6_9cfce8076f42row0_col5 {
#             background-color:  green;
#         }    #T_7cb6a8e2_51e9_11eb_9fc6_9cfce8076f42row1_col0 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Finance

# %%
pd.concat([convertible0.groupby('vehicle_financing').count().rename(columns={'trade_in':"convertible0"})[['convertible0']],
           convertible1.groupby('vehicle_financing').count().rename(columns={'trade_in':"convertible1"})[['convertible1']],
          convertible2.groupby('vehicle_financing').count().rename(columns={'trade_in':"convertible2"})[['convertible2']],
          convertible3.groupby('vehicle_financing').count().rename(columns={'trade_in':"convertible3"})[['convertible3']],
          convertible4.groupby('vehicle_financing').count().rename(columns={'trade_in':"convertible4"})[['convertible4']],
          convertible5.groupby('vehicle_financing').count().rename(columns={'trade_in':"convertible5"})[['convertible5']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_82ade1ad_51e9_11eb_9a50_9cfce8076f42row0_col3 {
#             background-color:  green;
#         }    #T_82ade1ad_51e9_11eb_9a50_9cfce8076f42row1_col0 {
#             background-color:  green;
#         }    #T_82ade1ad_51e9_11eb_9a50_9cfce8076f42row1_col1 {
#             background-color:  green;
#         }    #T_82ade1ad_51e9_11eb_9a50_9cfce8076f42row1_col2 {
#             background-color:  green;
#         }    #T_82ade1ad_51e9_11eb_9a50_9cfce8076f42row1_col4 {
#             background-color:  green;
#         }    #T_82ade1ad_51e9_11eb_9a50_9cfce8076f42row1_col5 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Age

# %%
pd.concat([convertible0.groupby('AgeBin').count().rename(columns={'trade_in':"convertible0"})[['convertible0']],
           convertible1.groupby('AgeBin').count().rename(columns={'trade_in':"convertible1"})[['convertible1']],
          convertible2.groupby('AgeBin').count().rename(columns={'trade_in':"convertible2"})[['convertible2']],
          convertible3.groupby('AgeBin').count().rename(columns={'trade_in':"convertible3"})[['convertible3']],
          convertible4.groupby('AgeBin').count().rename(columns={'trade_in':"convertible4"})[['convertible4']],
          convertible5.groupby('AgeBin').count().rename(columns={'trade_in':"convertible5"})[['convertible5']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_841038a5_51e9_11eb_9ed9_9cfce8076f42row2_col0 {
#             background-color:  green;
#         }    #T_841038a5_51e9_11eb_9ed9_9cfce8076f42row2_col3 {
#             background-color:  green;
#         }    #T_841038a5_51e9_11eb_9ed9_9cfce8076f42row2_col4 {
#             background-color:  green;
#         }    #T_841038a5_51e9_11eb_9ed9_9cfce8076f42row8_col1 {
#             background-color:  green;
#         }    #T_841038a5_51e9_11eb_9ed9_9cfce8076f42row8_col2 {
#             background-color:  green;
#         }    #T_841038a5_51e9_11eb_9ed9_9cfce8076f42row8_col5 {
#             background-color:  green;
# ...

# %% [markdown]
# <em>k</em>-means will partition your customers into three groups since we specified the algorithm to generate 3 clusters. The customers in each cluster are similar to each other in terms of the features included in the dataset.
#
# Now we can create a profile for each group, considering the common characteristics of each cluster.
# For example, the 3 clusters can be:
#
#     0. - Chevrolet
#        - Silverado 1500
#        - Late Twenties to Fifties
#        - Majority Customer Income Unkown "?"
#        - Finance
#        - Male
#        - Made U.S.
#        - More likely to not trade in a vehicle
#
#     1. - Ford
#        - F-150
#        - Late Twenties to Fifties
#        - Majority Income between $20k - $60k
#        - No Finance
#        - Male
#        - Made in US and Japan
#        - More likely to not trade in a vehicle
#
#     2. - Ford and Dodge
#        - RAM 1500 or F-150
#        - Late Twenties to Fifties
#        - Income between $60k - $80k
#        - Finance
#        - Male
#        - Made in U.S.
#        - More likely to not trade in a vehicle
#
#     3. - Ford
#        - F-150
#        - Late Twenties to Fifties
#        - Income $0 - $60k
#        - Finance
#        - Male
#        - Made in U.S.
#        - More likely to trade in
#
#     4. - Toyota
#        - Tacoma or Tundra
#        - Late Twenties to Fifties
#        - $20k - $60k
#        - Finance
#        - Male
#        - Made in Japan
#        - More likely to not trade in
