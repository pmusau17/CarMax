# %%
'''Load Packages'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import warnings
from sklearn.cluster import KMeans 
import random
from sklearn import metrics 
from scipy.spatial.distance import cdist

# %%
truck0 = pd.read_csv('clustersGrouped/truckCluster0.csv')
truck1 = pd.read_csv('clustersGrouped/truckCluster1.csv')
truck2 = pd.read_csv('clustersGrouped/truckCluster2.csv')
truck3 = pd.read_csv('clustersGrouped/truckCluster3.csv')
truck4 = pd.read_csv('clustersGrouped/truckCluster4.csv')

# %% [markdown]
# ### Purchase Make

# %%
pd.concat([truck0.groupby('purchase_make').count().rename(columns={'trade_in':"truck0"})[['truck0']],
           truck1.groupby('purchase_make').count().rename(columns={'trade_in':"truck1"})[['truck1']],
          truck2.groupby('purchase_make').count().rename(columns={'trade_in':"truck2"})[['truck2']],
          truck3.groupby('purchase_make').count().rename(columns={'trade_in':"truck3"})[['truck3']],
          truck4.groupby('purchase_make').count().rename(columns={'trade_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_cb9a497e_51de_11eb_9b5c_9cfce8076f42row0_col0 {
#             background-color:  green;
#         }    #T_cb9a497e_51de_11eb_9b5c_9cfce8076f42row5_col1 {
#             background-color:  green;
#         }    #T_cb9a497e_51de_11eb_9b5c_9cfce8076f42row5_col2 {
#             background-color:  green;
#         }    #T_cb9a497e_51de_11eb_9b5c_9cfce8076f42row5_col3 {
#             background-color:  green;
#         }    #T_cb9a497e_51de_11eb_9b5c_9cfce8076f42row13_col4 {
#             background-color:  green;
#         }</style><table id="T_cb9a497e_51de_11eb_9b5c_9cfce8076f42" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >truck0</th>        <th class="col_heading level0 col1" >truck1</th>        <th class="col_heading level0 col2" >truck2</th>        <th class="col_heading level0 col3" >truck3</th>        <th class="col_heading level0 col4" >truck4</th>    </tr></thead><tbody>
# ...

# %% [markdown]
# ### Purchase Model

# %%
pd.concat([truck0.groupby('purchase_model').count().rename(columns={'trade_in':"truck0"})[['truck0']],
           truck1.groupby('purchase_model').count().rename(columns={'trade_in':"truck1"})[['truck1']],
          truck2.groupby('purchase_model').count().rename(columns={'trade_in':"truck2"})[['truck2']],
          truck3.groupby('purchase_model').count().rename(columns={'trade_in':"truck3"})[['truck3']],
          truck4.groupby('purchase_model').count().rename(columns={'trade_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_79eee644_51e1_11eb_af2a_9cfce8076f42row6_col0 {
#             background-color:  green;
#         }    #T_79eee644_51e1_11eb_af2a_9cfce8076f42row16_col1 {
#             background-color:  green;
#         }    #T_79eee644_51e1_11eb_af2a_9cfce8076f42row16_col3 {
#             background-color:  green;
#         }    #T_79eee644_51e1_11eb_af2a_9cfce8076f42row24_col2 {
#             background-color:  green;
#         }    #T_79eee644_51e1_11eb_af2a_9cfce8076f42row38_col4 {
#             background-color:  green;
#         }</style><table id="T_79eee644_51e1_11eb_af2a_9cfce8076f42" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >truck0</th>        <th class="col_heading level0 col1" >truck1</th>        <th class="col_heading level0 col2" >truck2</th>        <th class="col_heading level0 col3" >truck3</th>        <th class="col_heading level0 col4" >truck4</th>    </tr></thead><tbody>
# ...

# %% [markdown]
# ### Customer_Income

# %%
pd.concat([truck0.groupby('customer_income').count().rename(columns={'trade_in':"truck0"})[['truck0']],
           truck1.groupby('customer_income').count().rename(columns={'trade_in':"truck1"})[['truck1']],
          truck2.groupby('customer_income').count().rename(columns={'trade_in':"truck2"})[['truck2']],
          truck3.groupby('customer_income').count().rename(columns={'trade_in':"truck3"})[['truck3']],
          truck4.groupby('customer_income').count().rename(columns={'trade_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_fc3fdbd3_51de_11eb_8bc7_9cfce8076f42row8_col0 {
#             background-color:  green;
#         }    #T_fc3fdbd3_51de_11eb_8bc7_9cfce8076f42row8_col2 {
#             background-color:  green;
#         }    #T_fc3fdbd3_51de_11eb_8bc7_9cfce8076f42row8_col4 {
#             background-color:  green;
#         }    #T_fc3fdbd3_51de_11eb_8bc7_9cfce8076f42row9_col3 {
#             background-color:  green;
#         }    #T_fc3fdbd3_51de_11eb_8bc7_9cfce8076f42row11_col1 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Made_In

# %%
pd.concat([truck0.groupby('made_in').count().rename(columns={'trade_in':"truck0"})[['truck0']],
           truck1.groupby('made_in').count().rename(columns={'trade_in':"truck1"})[['truck1']],
          truck2.groupby('made_in').count().rename(columns={'trade_in':"truck2"})[['truck2']],
          truck3.groupby('made_in').count().rename(columns={'trade_in':"truck3"})[['truck3']],
          truck4.groupby('made_in').count().rename(columns={'trade_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_0c83f224_51df_11eb_845f_9cfce8076f42row0_col0 {
#             background-color:  green;
#         }    #T_0c83f224_51df_11eb_845f_9cfce8076f42row0_col1 {
#             background-color:  green;
#         }    #T_0c83f224_51df_11eb_845f_9cfce8076f42row0_col2 {
#             background-color:  green;
#         }    #T_0c83f224_51df_11eb_845f_9cfce8076f42row0_col3 {
#             background-color:  green;
#         }    #T_0c83f224_51df_11eb_845f_9cfce8076f42row1_col4 {
#             background-color:  green;
#         }</style><table id="T_0c83f224_51df_11eb_845f_9cfce8076f42" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >truck0</th>        <th class="col_heading level0 col1" >truck1</th>        <th class="col_heading level0 col2" >truck2</th>        <th class="col_heading level0 col3" >truck3</th>        <th class="col_heading level0 col4" >truck4</th>    </tr></thead><tbody>
# ...

# %% [markdown]
# ### Customer_Gender

# %%
pd.concat([truck0.groupby('customer_gender').count().rename(columns={'trade_in':"truck0"})[['truck0']],
           truck1.groupby('customer_gender').count().rename(columns={'trade_in':"truck1"})[['truck1']],
          truck2.groupby('customer_gender').count().rename(columns={'trade_in':"truck2"})[['truck2']],
          truck3.groupby('customer_gender').count().rename(columns={'trade_in':"truck3"})[['truck3']],
          truck4.groupby('customer_gender').count().rename(columns={'trade_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_abb45e3c_51df_11eb_b116_9cfce8076f42row1_col0 {
#             background-color:  green;
#         }    #T_abb45e3c_51df_11eb_b116_9cfce8076f42row1_col1 {
#             background-color:  green;
#         }    #T_abb45e3c_51df_11eb_b116_9cfce8076f42row1_col2 {
#             background-color:  green;
#         }    #T_abb45e3c_51df_11eb_b116_9cfce8076f42row1_col3 {
#             background-color:  green;
#         }    #T_abb45e3c_51df_11eb_b116_9cfce8076f42row1_col4 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Trade_In

# %%
pd.concat([truck0.groupby('trade_in').count().rename(columns={'made_in':"truck0"})[['truck0']],
           truck1.groupby('trade_in').count().rename(columns={'made_in':"truck1"})[['truck1']],
          truck2.groupby('trade_in').count().rename(columns={'made_in':"truck2"})[['truck2']],
          truck3.groupby('trade_in').count().rename(columns={'made_in':"truck3"})[['truck3']],
          truck4.groupby('trade_in').count().rename(columns={'made_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_aaa3b0af_51df_11eb_b0a9_9cfce8076f42row0_col0 {
#             background-color:  green;
#         }    #T_aaa3b0af_51df_11eb_b0a9_9cfce8076f42row0_col1 {
#             background-color:  green;
#         }    #T_aaa3b0af_51df_11eb_b0a9_9cfce8076f42row0_col2 {
#             background-color:  green;
#         }    #T_aaa3b0af_51df_11eb_b0a9_9cfce8076f42row0_col4 {
#             background-color:  green;
#         }    #T_aaa3b0af_51df_11eb_b0a9_9cfce8076f42row1_col3 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Finance

# %%
pd.concat([truck0.groupby('vehicle_financing').count().rename(columns={'trade_in':"truck0"})[['truck0']],
           truck1.groupby('vehicle_financing').count().rename(columns={'trade_in':"truck1"})[['truck1']],
          truck2.groupby('vehicle_financing').count().rename(columns={'trade_in':"truck2"})[['truck2']],
          truck3.groupby('vehicle_financing').count().rename(columns={'trade_in':"truck3"})[['truck3']],
          truck4.groupby('vehicle_financing').count().rename(columns={'trade_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_2780b06a_51df_11eb_abb8_9cfce8076f42row0_col1 {
#             background-color:  green;
#         }    #T_2780b06a_51df_11eb_abb8_9cfce8076f42row1_col0 {
#             background-color:  green;
#         }    #T_2780b06a_51df_11eb_abb8_9cfce8076f42row1_col2 {
#             background-color:  green;
#         }    #T_2780b06a_51df_11eb_abb8_9cfce8076f42row1_col3 {
#             background-color:  green;
#         }    #T_2780b06a_51df_11eb_abb8_9cfce8076f42row1_col4 {
#             background-color:  green;
# ...

# %% [markdown]
# ### Age

# %%
pd.concat([truck0.groupby('AgeBin').count().rename(columns={'trade_in':"truck0"})[['truck0']],
           truck1.groupby('AgeBin').count().rename(columns={'trade_in':"truck1"})[['truck1']],
          truck2.groupby('AgeBin').count().rename(columns={'trade_in':"truck2"})[['truck2']],
          truck3.groupby('AgeBin').count().rename(columns={'trade_in':"truck3"})[['truck3']],
          truck4.groupby('AgeBin').count().rename(columns={'trade_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_35dd2676_51df_11eb_b72c_9cfce8076f42row2_col0 {
#             background-color:  green;
#         }    #T_35dd2676_51df_11eb_b72c_9cfce8076f42row2_col1 {
#             background-color:  green;
#         }    #T_35dd2676_51df_11eb_b72c_9cfce8076f42row2_col2 {
#             background-color:  green;
#         }    #T_35dd2676_51df_11eb_b72c_9cfce8076f42row2_col3 {
#             background-color:  green;
#         }    #T_35dd2676_51df_11eb_b72c_9cfce8076f42row2_col4 {
#             background-color:  green;
#         }</style><table id="T_35dd2676_51df_11eb_b72c_9cfce8076f42" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >truck0</th>        <th class="col_heading level0 col1" >truck1</th>        <th class="col_heading level0 col2" >truck2</th>        <th class="col_heading level0 col3" >truck3</th>        <th class="col_heading level0 col4" >truck4</th>    </tr></thead><tbody>
# ...

# %% [markdown]
# <em>k</em>-means will partition your customers into three groups since we specified the algorithm to generate 3 clusters. The customers in each cluster are similar to each other in terms of the features included in the dataset.
#
# Now we can create a profile for each group, considering the common characteristics of each cluster.
# For example, the 3 clusters can be:
#
#     0. - Chevrolet
#        - Silverado 1500
#        - Late Twenties to Fifties
#        - Majority Customer Income Unkown "?"
#        - Finance
#        - Male
#        - Made U.S.
#        - More likely to not trade in a vehicle
#
#     1. - Ford
#        - F-150
#        - Late Twenties to Fifties
#        - Majority Income between $20k - $60k
#        - No Finance
#        - Male
#        - Made in US and Japan
#        - More likely to not trade in a vehicle
#
#     2. - Ford and Dodge
#        - RAM 1500 or F-150
#        - Late Twenties to Fifties
#        - Income between $60k - $80k
#        - Finance
#        - Male
#        - Made in U.S.
#        - More likely to not trade in a vehicle
#
#     3. - Ford
#        - F-150
#        - Late Twenties to Fifties
#        - Income $0 - $60k
#        - Finance
#        - Male
#        - Made in U.S.
#        - More likely to trade in
#
#     4. - Toyota
#        - Tacoma or Tundra
#        - Late Twenties to Fifties
#        - $20k - $60k
#        - Finance
#        - Male
#        - Made in Japan
#        - More likely to not trade in

# %%
pd.concat([truck0.groupby('job_assign').count().rename(columns={'trade_in':"truck0"})[['truck0']],
           truck1.groupby('job_assign').count().rename(columns={'trade_in':"truck1"})[['truck1']],
          truck2.groupby('job_assign').count().rename(columns={'trade_in':"truck2"})[['truck2']],
          truck3.groupby('job_assign').count().rename(columns={'trade_in':"truck3"})[['truck3']],
          truck4.groupby('job_assign').count().rename(columns={'trade_in':"truck4"})[['truck4']]],axis=1).fillna(0).style.highlight_max(color = 'green').format(int)
# Out:
# <style  type="text/css" >
#     #T_6a8be7b0_51f1_11eb_a2c8_9cfce8076f42row423_col0 {
#             background-color:  green;
#         }    #T_6a8be7b0_51f1_11eb_a2c8_9cfce8076f42row423_col1 {
#             background-color:  green;
#         }    #T_6a8be7b0_51f1_11eb_a2c8_9cfce8076f42row423_col2 {
#             background-color:  green;
#         }    #T_6a8be7b0_51f1_11eb_a2c8_9cfce8076f42row771_col3 {
#             background-color:  green;
#         }    #T_6a8be7b0_51f1_11eb_a2c8_9cfce8076f42row771_col4 {
#             background-color:  green;
#         }</style><table id="T_6a8be7b0_51f1_11eb_a2c8_9cfce8076f42" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >truck0</th>        <th class="col_heading level0 col1" >truck1</th>        <th class="col_heading level0 col2" >truck2</th>        <th class="col_heading level0 col3" >truck3</th>        <th class="col_heading level0 col4" >truck4</th>    </tr></thead><tbody>
# ...

# %%
truck0
# Out:
#      purchase_make  purchase_model  purchase_vehicle_year  purchase_price_LB  \
# 0              GMC     SIERRA 1500                   2009            20001.0
# 1        CHEVROLET  SILVERADO 1500                   2007            15001.0
# 2              GMC     SIERRA 1500                   2006            20001.0
# 3        CHEVROLET  SILVERADO 1500                   2003            10001.0
# 4              GMC     SIERRA 1500                   2012            20001.0
# ...            ...             ...                    ...                ...
# 5831     CHEVROLET  SILVERADO 1500                   2011            20001.0
# 5832     CHEVROLET  SILVERADO 1500                   2009            15001.0
# 5833     CHEVROLET  SILVERADO 1500                   2004             5001.0
# 5834     CHEVROLET  SILVERADO 1500                   2009            10001.0
# 5835     CHEVROLET  SILVERADO 1500                   2011            20001.0
#
# ...
